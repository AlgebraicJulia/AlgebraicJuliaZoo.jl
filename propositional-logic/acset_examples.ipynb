# %% [markdown]
# # Examples of How To Define ACSets
#
# Nelson Niu
# Nathaniel Osgood
# Priyaa Srinivasan
# Jacob Zelko
# Juxin Liu
# 2026-02-26
#
# ## Background
#
# ## Catlab Set-Up

# %%
import Catlab.CategoricalAlgebra:
  @acset,
  @acset_type,
  @acset_colim,
  @present,
  FreeSchema,
  elements,
  nparts,
  representable,
  set_subpart!,
  src,
  subobject_classifier,
  tgt,
  yoneda
import Catlab.Graphs:
  NamedGraph
import Catlab.Graphics:
  to_graphviz
import Catlab.Graphics.Graphviz: 
  run_graphviz

# %%
ng = NamedGraph{Symbol, Symbol}
# Out:
# NamedGraph{Symbol, Symbol}

# %%
y_ng = yoneda(ng)
# Out:
# Catlab.CategoricalAlgebra.Cats.FinFunctors.FinDomMap.FinDomFunctorMap{Union{Catlab.Theories.FreeSchema.AttrType{:generator}, Catlab.Theories.FreeSchema.Ob{:generator}}, ACSets.ACSetInterface.ACSet, Union{Catlab.Theories.FreeSchema.Attr, Catlab.Theories.FreeSchema.Hom}, Catlab.CategoricalAlgebra.Pointwise.ACSetTransformations.ACSetTransformation, Union{Catlab.Theories.FreeSchema.Attr{:generator}, Catlab.Theories.FreeSchema.Hom{:generator}}, Dict{GATlab.Models.SymbolicModels.GATExpr{:generator}, NamedGraph{Symbol, Symbol}}, Dict{GATlab.Models.SymbolicModels.GATExpr{:generator}, Catlab.CategoricalAlgebra.Pointwise.ACSetTransformations.StructACSetTransformation{ACSets.Schemas.TypeLevelBasicSchema{Symbol, Tuple{:V, :E}, Tuple{(:src, :E, :V), (:tgt, :E, :V)}, Tuple{:VName, :EName}, Tuple{(:vname, :V, :VName), (:ename, :E, :EName)}, Tuple{}}, @NamedTuple{VName::Catlab.BasicSets.CopairedFinDomFunctions.CopairedFinDomFunction{Symbol, Int64, Int64}, EName::Catlab.BasicSets.CopairedFinDomFunctions.CopairedFinDomFunction{Symbol, Int64, Int64}, V::Catlab.BasicSets.FinFunctions.FinFunction, E::Catlab.BasicSets.FinFunctions.FinFunction}, NamedGraph{Symbol, Symbol}, NamedGraph{Symbol, Symbol}}}, Catlab.CategoricalAlgebra.Cats.Categories.Category}(Dict{GATlab.Models.SymbolicModels.GATExpr{:generator}, NamedGraph{Symbol, Symbol}}(VName => Catlab.Graphs.NamedGraphs.NamedGraph{Symbol, Symbol}:
#   V = 1:0
#   E = 1:0
#   VName = 1:1
#   EName = 1:0
#   src : E → V = Int64[]
#   tgt : E → V = Int64[]
#   vname : V → VName = Symbol[]
#   ename : E → EName = Symbol[], E => Catlab.Graphs.NamedGraphs.NamedGraph{Symbol, Symbol}:
#   V = 1:2
#   E = 1:1
#   VName = 1:2
#   EName = 1:1
#   src : E → V = [2]
#   tgt : E → V = [1]
#   vname : V → VName = ACSets.ColumnImplementations.AttrVar[ACSets.ColumnImplementations.AttrVar(1), ACSets.ColumnImplementations.AttrVar(2)]
#   ename : E → EName = ACSets.ColumnImplementations.AttrVar[ACSets.ColumnImplementations.AttrVar(1)], V => Catlab.Graphs.NamedGraphs.NamedGraph{Symbol, Symbol}:
#   V = 1:1
#   E = 1:0
#   VName = 1:1
#   EName = 1:0
#   src : E → V = Int64[]
#   tgt : E → V = Int64[]
#   vname : V → VName = ACSets.ColumnImplementations.AttrVar[ACSets.ColumnImplementations.AttrVar(1)]
#   ename : E → EName = Symbol[], EName => Catlab.Graphs.NamedGraphs.NamedGraph{Symbol, Symbol}:
#   V = 1:0
#   E = 1:0
#   VName = 1:0
#   EName = 1:1
#   src : E → V = Int64[]
#   tgt : E → V = Int64[]
#   vname : V → VName = Symbol[]
#   ename : E → EName = Symbol[]), Dict{GATlab.Models.SymbolicModels.GATExpr{:generator}, Catlab.CategoricalAlgebra.Pointwise.ACSetTransformations.StructACSetTransformation{ACSets.Schemas.TypeLevelBasicSchema{Symbol, Tuple{:V, :E}, Tuple{(:src, :E, :V), (:tgt, :E, :V)}, Tuple{:VName, :EName}, Tuple{(:vname, :V, :VName), (:ename, :E, :EName)}, Tuple{}}, @NamedTuple{VName::Catlab.BasicSets.CopairedFinDomFunctions.CopairedFinDomFunction{Symbol, Int64, Int64}, EName::Catlab.BasicSets.CopairedFinDomFunctions.CopairedFinDomFunction{Symbol, Int64, Int64}, V::Catlab.BasicSets.FinFunctions.FinFunction, E::Catlab.BasicSets.FinFunctions.FinFunction}, NamedGraph{Symbol, Symbol}, NamedGraph{Symbol, Symbol}}}(src => ACSetTransformation((VName = Catlab.BasicSets.CopairedFinDomFunctions.CopairedFinDomFunction{Symbol, Int64, Int64}(FinDomFunction(GATlab.Util.Eithers.Left{Int64}[GATlab.Util.Eithers.Left{Int64}(2)], Catlab.BasicSets.EitherSets.EitherSet{Catlab.BasicSets.FinSets.FinSet, Catlab.BasicSets.Sets.SetOb, Union{GATlab.Util.Eithers.Left{Int64}, GATlab.Util.Eithers.Right{Symbol}}}(FinSet(2), TypeSet(Symbol))), TypeSet(Symbol), FinSet(1), FinSet(2)), EName = Catlab.BasicSets.CopairedFinDomFunctions.CopairedFinDomFunction{Symbol, Int64, Int64}(FinDomFunction(Any[], Catlab.BasicSets.EitherSets.EitherSet{Catlab.BasicSets.FinSets.FinSet, Catlab.BasicSets.Sets.SetOb, Union{GATlab.Util.Eithers.Left{Int64}, GATlab.Util.Eithers.Right{Symbol}}}(FinSet(1), TypeSet(Symbol))), TypeSet(Symbol), FinSet(0), FinSet(1)), V = FinFunction([2], FinSet(2)), E = FinFunction(Int64[], FinSet(1))), ), tgt => ACSetTransformation((VName = Catlab.BasicSets.CopairedFinDomFunctions.CopairedFinDomFunction{Symbol, Int64, Int64}(FinDomFunction(GATlab.Util.Eithers.Left{Int64}[GATlab.Util.Eithers.Left{Int64}(1)], Catlab.BasicSets.EitherSets.EitherSet{Catlab.BasicSets.FinSets.FinSet, Catlab.BasicSets.Sets.SetOb, Union{GATlab.Util.Eithers.Left{Int64}, GATlab.Util.Eithers.Right{Symbol}}}(FinSet(2), TypeSet(Symbol))), TypeSet(Symbol), FinSet(1), FinSet(2)), EName = Catlab.BasicSets.CopairedFinDomFunctions.CopairedFinDomFunction{Symbol, Int64, Int64}(FinDomFunction(Any[], Catlab.BasicSets.EitherSets.EitherSet{Catlab.BasicSets.FinSets.FinSet, Catlab.BasicSets.Sets.SetOb, Union{GATlab.Util.Eithers.Left{Int64}, GATlab.Util.Eithers.Right{Symbol}}}(FinSet(1), TypeSet(Symbol))), TypeSet(Symbol), FinSet(0), FinSet(1)), V = FinFunction([1], FinSet(2)), E = FinFunction(Int64[], FinSet(1))), ), ename => ACSetTransformation((VName = Catlab.BasicSets.CopairedFinDomFunctions.CopairedFinDomFunction{Symbol, Int64, Int64}(FinDomFunction(Any[], Catlab.BasicSets.EitherSets.EitherSet{Catlab.BasicSets.FinSets.FinSet, Catlab.BasicSets.Sets.SetOb, Union{GATlab.Util.Eithers.Left{Int64}, GATlab.Util.Eithers.Right{Symbol}}}(FinSet(2), TypeSet(Symbol))), TypeSet(Symbol), FinSet(0), FinSet(2)), EName = Catlab.BasicSets.CopairedFinDomFunctions.CopairedFinDomFunction{Symbol, Int64, Int64}(FinDomFunction(GATlab.Util.Eithers.Left{Int64}[GATlab.Util.Eithers.Left{Int64}(1)], Catlab.BasicSets.EitherSets.EitherSet{Catlab.BasicSets.FinSets.FinSet, Catlab.BasicSets.Sets.SetOb, Union{GATlab.Util.Eithers.Left{Int64}, GATlab.Util.Eithers.Right{Symbol}}}(FinSet(1), TypeSet(Symbol))), TypeSet(Symbol), FinSet(1), FinSet(1)), V = FinFunction(Int64[], FinSet(2)), E = FinFunction(Int64[], FinSet(1))), ), vname => ACSetTransformation((VName = Catlab.BasicSets.CopairedFinDomFunctions.CopairedFinDomFunction{Symbol, Int64, Int64}(FinDomFunction(GATlab.Util.Eithers.Left{Int64}[GATlab.Util.Eithers.Left{Int64}(1)], Catlab.BasicSets.EitherSets.EitherSet{Catlab.BasicSets.FinSets.FinSet, Catlab.BasicSets.Sets.SetOb, Union{GATlab.Util.Eithers.Left{Int64}, GATlab.Util.Eithers.Right{Symbol}}}(FinSet(1), TypeSet(Symbol))), TypeSet(Symbol), FinSet(1), FinSet(1)), EName = Catlab.BasicSets.CopairedFinDomFunctions.CopairedFinDomFunction{Symbol, Int64, Int64}(FinDomFunction(Any[], Catlab.BasicSets.EitherSets.EitherSet{Catlab.BasicSets.FinSets.F ...

# %%
ng1 = @acset_colim y_ng begin
  # First Component
  (v1,v2,v3,v4,v5,v6)::V
  (e1,e2,e3,e4,e5,e6)::E

  # To reduce brutal repetition, like "ename(e6) == $(:E6);" for each edge, we will perform this naming below in a single comprehension.
  src(e1) == v1; tgt(e1)==v2;
  src(e2) == v2; tgt(e2)==v3;
  src(e3) == v2; tgt(e3)==v3;
  src(e4) == v4; tgt(e4)==v2;
  src(e5) == v4; tgt(e5)==v5;
  src(e6) == v6; tgt(e6)==v5;


  # Second component
  (v7,v8,v9)::V
  (e7,e8)::E

  src(e7) == v7; tgt(e7) == v8;
  src(e8) == v7; tgt(e8) == v9;


  # Third component
  (v10)::V
end
# Out:
# </div>

# %%
set_subpart!(ng1, :ename, Symbol.("E$e" for e in 1:nparts(ng1, :E)));

# %%
set_subpart!(ng1, :vname, Symbol.("V$v" for v in 1:nparts(ng1, :V)));

# %%
to_graphviz(ng1, node_labels=true, edge_labels=true)

# %%
# We now declaratively characterize this in traditional syntax

# %%
graph_1Manual = @acset ng begin
  V = 10
  E = 8

  src = [1, 2, 2, 4, 4, 6, 7, 7] # Source vector
  tgt = [2, 3, 3, 2, 5, 5, 8, 9]  # Target vector
end
# Out:
# </div>

# %%
set_subpart!(graph_1Manual, :vname, Symbol.("V$v" for v in 1:10));

# %%
set_subpart!(graph_1Manual, :ename, Symbol.("E$e" for e in 1:8));
